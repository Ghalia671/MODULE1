# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghalia671/MODULE1/blob/master/Exemple_4_2_arbre_de_de%CC%81cision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
df = pd.DataFrame(data=cancer['data'], columns = cancer["feature_names"])
df["target"]=cancer['target']

# %%
import matplotlib.pyplot as plt

plt.scatter(df["mean radius"], y=df["target"],c=df["target"])
plt.xlabel("mean radius")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(max_depth=3)

# %%
X=df[["mean radius"]]
y=df["target"]

# %%
dtc.fit(X,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn.tree import plot_tree
plot_tree(dtc,filled=True,impurity=True)
plt.show()

# %%
plt.figure(figsize=(20,10))
plot_tree(dtc,filled=True,impurity=True)
plt.show()

# %%
X=df[["mean radius","mean smoothness"]]
plt.scatter(df["mean radius"], y=df["mean smoothness"],c=df["target"])

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(max_depth=2)
dtc.fit(X,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=2, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
plt.figure(figsize=(10,10))
plot_tree(dtc,filled=True,impurity=True)
plt.show()
